# %%
print('starting3')
# Out:
# starting3

# %%
#!pip install msoffcrypto-tool
# needed to read password-protected file

# %%
from getpass import getpass
import io
import pandas as pd
import msoffcrypto

file_path =r"C:\Users\danam\OneDrive\Desktop\Bachelorprojekt\Tidligere excel bearbejdninger\Alle Giftlinjen 2018-2022 (anonym) Aldersfordelt - Kopi.xlsx"
password = getpass("Enter Excel password: ")

decrypted = io.BytesIO()
with open(file_path, "rb") as f:
    office = msoffcrypto.OfficeFile(f)
    office.load_key(password=password)
    office.decrypt(decrypted)

# Move back to the start of the stream before reading
decrypted.seek(0)

# Specify the two sheets you want to load
sheet_names = ["Alder<70", "Alder>70"] 
# List the columns you want
keep = [
    '[Indtag tid(gift1)]',
    '[Mand(Patient data)]',
    '[Alder (år)(Patient data)]',
    '[Ingen risiko(Risiko)]',
    '[generisk navn(gift1)]',
    '[navn(gift1)]',
    '[substans type(gift1)]',
    '[Enhed(gift1)]',
    '[Styrke(gift1)]',
    '[antal(gift1)]',
    '[dosis(gift1)]',
    '[generisk navn(gift2)]',
    '[navn(gift2)]',
    '[substans type(gift2)]',
    '[Enhed(gift2)]',
    '[Styrke(gift2)]',
    '[antal(gift2)]',
    '[dosis(gift2)]',
    '[generisk navn(gift3)]',
    '[navn(gift3)]',
    '[substans type(gift3)]',
    '[Enhed(gift3)]',
    '[Styrke(gift3)]',
    '[antal(gift3)]',
    '[dosis(gift3)]',
    '[generisk navn(gift4)]',
    '[navn(gift4)]',
    '[substans type(gift4)]',
    '[Enhed(gift4)]',
    '[Styrke(gift4)]',
    '[antal(gift4)]',
    '[dosis(gift4)]',  
    '[generisk navn(gift5)]',
    '[navn(gift5)]',
    '[substans type(gift5)]',
    '[Enhed(gift5)]',
    '[Styrke(gift5)]',
    '[antal(gift5)]',
    '[dosis(gift5)]',
    '[generisk navn(gift6)]',
    '[navn(gift6)]',
    '[substans type(gift6)]',
    '[Enhed(gift6)]',
    '[Styrke(gift6)]',
    '[antal(gift6)]',
    '[Dosis(gift6)]',
    '[generisk navn(gift7)]',
    '[navn(gift7)]',
    '[substans type(gift7)]',
    '[Enhed(gift7)]',
    '[Styrke(gift7)]',
    '[antal(gift7)]',
    '[Dosis(gift7)]',
    '[generisk navn(gift8)]',
    '[navn(gift8)]',
    '[substans type(gift8)]',
    '[Enhed(gift8)]',
    '[Styrke(gift8)]',
    '[antal(gift8)]',
    '[Dosis(gift8)]',
    '[generisk navn(gift9)]',
    '[navn(gift9)]',
    '[substans type(gift9)]',
    '[Enhed(gift9)]',
    '[Styrke(gift9)]',
    '[antal(gift9)]',
    '[Dosis(gift9)]',
    '[generisk navn(gift10)]',
    '[navn(gift10)]',
    '[substans type(gift10)]',
    '[Enhed(gift10)]',
    '[Styrke(gift10)]',
    '[antal(gift10)]',
    '[Dosis(gift10)]',
    '[generisk navn(gift11)]',
    '[navn(gift11)]',
    '[substans type(gift11)]',
    '[Enhed(gift11)]',
    '[Styrke(gift11)]',
    '[antal(gift11)]',
    '[Dosis(gift11)]',
    '[generisk navn(gift12)]',
    '[navn(gift12)]',
    '[substans type(gift12)]',
    '[Enhed(gift12)]',
    '[Styrke(gift12)]',
    '[antal(gift12)]',
    '[Dosis(gift12)]',
    '[generisk navn(gift13)]',
    '[navn(gift13)]',
    '[substans type(gift13)]',
    '[Enhed(gift13)]',
    '[Styrke(gift13)]',
    '[antal(gift13)]',
    '[Dosis(gift13)]',
    '[generisk navn(gift14)]',
    '[navn(gift14)]',
    '[substans type(gift14)]',
    '[Enhed(gift14)]',
    '[Styrke(gift14)]',
    '[antal(gift14)]',
    '[Dosis(gift14)]',
    '[generisk navn(gift15)]',
    '[navn(gift15)]',
    '[substans type(gift15)]',
    '[Enhed(gift15)]',
    '[Styrke(gift15)]',
    '[antal(gift15)]',
    '[Dosis(gift15)]',
    '[Ingen(Anbefalet obs)]',
    '[Akut forgiftning(Forespørgselsart)]',
    '[Søg Hospital(hospital)]',
    '[Borger(Spørger1)]',
    '[Søg postnummer(postalcode)]',
    '[Søg By(postalcode)]',
    '[Råd(Tekst)]',
    '[Today(Oprettelse)]',
    '[Anamnese(Tekst)]',
    '[Psykiatriske sygdomme(Komorbiditet)]',
    '[Ulykke/uheld(Årsag)]',
    '[Leg(Årsag)]',
    '[Suicidal/Affekt(Årsag)]',
    '[Misbrug(Årsag)]',
    '[Forveksling(Årsag)]',
    '[Omhældning(Årsag)]',
    '[Fejldosering(Årsag)]',
    '[Levnedsmiddel(Årsag)]',
]

dfs = pd.read_excel(
    decrypted,
    sheet_name=sheet_names,
    usecols=keep
)

# All column names are now lowercase:
for sheet in sheet_names:
    dfs[sheet].columns = [c.lower() for c in dfs[sheet].columns]


young = dfs[sheet_names[0]]
old = dfs[sheet_names[1]]

# %%
display(young.head())
display(old.head())
# Out:
#              [ingen risiko(risiko)] [generisk navn(gift1)] [styrke(gift1)]  \
# 0   Risiko for manifest forgiftning               Cannabis             NaN
# 1                      Ingen risiko                    NaN             NaN
# 2                  Uafklaret risiko                 Ukendt             NaN
# 3  Risiko for begrænset forgiftning       Ukendt rusmiddel             NaN
# 4                      Ingen risiko            PARACETAMOL             500
#
#   [antal(gift1)]  [indtag tid(gift1)] [dosis(gift1)] [ingen(anbefalet obs)]  \
# 0            NaN  2021-12-31 05:00:36            NaN            Indlæggelse
# 1            NaN  2022-01-01 14:03:44            NaN                  Ingen
# 2              1  2022-01-01 15:24:37            NaN                  Ingen
# 3            NaN  2022-01-01 02:00:14            NaN      Observeres hjemme
# 4              1  2022-01-01 15:32:13            500                  Ingen
#
# ...

# %%
#Finding unique values and counting them
import numpy as np
from collections import Counter

# Define the columns
generisk_cols = [f'[generisk navn(gift{i})]' for i in range(1, 16)]
navn_cols = [f'[navn(gift{i})]' for i in range(1, 16)]

# All relevant columns (already lowercased in your code)
columns = [c.lower() for c in generisk_cols + navn_cols]

# Extract the values from both dataframes
def get_values(df, columns):
    vals = []
    for col in columns:
        if col in df.columns:
            # dropna (empty cells)
            vals.extend(df[col].dropna().astype(str))
    return vals

all_vals = get_values(young, columns) + get_values(old, columns)

# Normalize and clean: lowercase, strip whitespace, remove empty/nan/none
cleaned_vals = []
for val in all_vals:
    v = val.lower().strip()
    if not v or v in ['nan', 'none', '']:  # skip empty/nan entries
        continue
    v = v.replace(',', '')  # Remove commas so output is comma-free
    cleaned_vals.append(v)

# Count unique values
counter = Counter(cleaned_vals)

# Write output: name TAB count, one per line
with open('raw_unique_values.csv', 'w', encoding='utf-8') as f:
    for name, count in counter.most_common():
        f.write(f"{name}\t{count}\n")

print(f"Done. Found {len(counter)} unique names. Output is in 'raw_unique_values.csv'.")
# Out:
# Done. Found 24319 unique names. Output is in 'raw_unique_values.csv'.

# %%
# Second processed list of medicines, now including new entries
know_medicines_in_categories = {
    "antihypertensives_cardiovascular": {
        "amlodipin", "amlodipine", "amlodipinbesilat", "amlodipinmaleat", "amlodipinmesilat", "amlodipinbesilat valsartan", "amlodipin \\sandoz\\\"",
        "amlodipin \\orion\\\"", "amlodipin \\actavis\\\"", "amlodipin \\1a farma\\\"", "amlodipin \\pfizer\\\"", "amlodipin \\bluefish\\\"", "amlodipin \\hexal\\\"",
        "ramipril", "ramipril \\teva\\\"", "ramipril \\pfizer\\\"", "ramipril \\stada\\\"", "ramipril \\actavis\\\"",
        "losartan", "losartankalium \\teva\\\"", "losartan \\jubilant\\\"", "losartankalium \\krka\\\"", "losartan \\bluefish\\\"", "losartan \\agp\\\"",
        "losartankalium/hydrochlorthiazid \\teva\\\"", "losartan/hydroklortiazid \\teva\\\"", "losartankalium \\pfizer\\\"",
        "metoprololsuccinat", "metoprololsuccinat \\teva\\\"", "metoprololsuccinat \\hexal\\\"", "metoprololsuccinat \\stada\\\"", "metoprolol",
        "metoprolol \\gea\\\"", "metoprololsuccinat \\orion\\\"", "metoprololsuccinat \\farmaprojects\\\"", "metoprolol retard", "metoprololsuccinat \\polpharma\\\"",
        "atenolol", "atenolol \\sandoz\\\"",
        "valsartan", "valsartan \\krka\\\"",
        "bisoprolol", "bisoprolol \\sandoz\\\"", "bisoprolol \\pfizer\\\"", "bisoprololfumarat",
        "carvedilol", "carvedilol \\teva\\\"", "carvedilol \\krka\\\"", "carvedilol \\arrow\\\"",
        "enalapril", "enalapril \\teva\\\"", "enalapril \\vitabalans\\\"", "enalapril \\mylan\\\"", "enalaprilmaleat hydrochlorthiazid",
        "enalaprilmaleat lercanidipinhydrochlorid", "enalapril hydrochlorthiazid \\teva\\\"", "enalapril \\krka\\\"", "enalapril \\farmaprojects\\\"", "enalaprilmaleat"
        "spironolacton", "spironolactone \\orion\\\"",
        "furosemid", "furosemid \\hexal\\\"",
        "moxonidin",
        "amiloridhydrochlorid dihydrat hydrochlorthiazid",  # newly added, diuretic mix
        "candesartan",  # ARB
        "digoxin",
        "simvastatin", "atorvastatin",  # statins
        "clopidogrel", # antiplatelet
        "clonidin", "clonidinhydrochlorid",
        "propranololhydrochlorid", "propranolol",
        "magnesiumsulfat", #heart medication
        "warfarin", "eliquis", "apixaban",

    },
    "antidepressants": {
        "sertralin", "sertralinhydrochlorid", "sertralin \\teva\\\"", "sertralin \\hexal\\\"", "sertralin \\krka\\\"", "sertralin \\bluefish\\\"", "sertralin \\pfizer\\\"", "sertralin \\orion\\\"",
        "mirtazapin", "mirtazapin \\teva\\\"", "mirtazapin \\bluefish\\\"", "mirtazapin \\aurobindo\\\"", "mirtazapin \\actavis\\\"", "mirtazapin \\stada\\\"", "mirtazapin \\orion\\\"", "mirtazapin \\hexal\\\"", "mirtazapin \\medis\\\"",
        "venlafaxin", "venlafaxinhydrochlorid", "venlafaxin \\stada\\\"", "venlafaxin \\sandoz\\\"", "venlafaxin \\2care4\\\"", "venlafaxin \\hexal\\\"", "venlafaxin \\actavis\\\"", "venlafaxin \\bluefish\\\"", "venlafaxin \\krka\\\"", "venlafaxin \\pharmathen\\\"",
        "duloxetin", "duloxetinhydrochlorid", "duloxetin \\sandoz\\\"",
        "escitalopram", "escitalopramoxalat", "escitalopram \\teva\\\"", "escitalopram \\mithridatum\\\"", "escitalopram \\stada\\\"",
        "paroxetin", "paroxetinhydrochloridhemihydrat", "paroxetin \\mylan\\\"", "paroxetin \\orion\\\"", "paroxetin \\hexal\\\"", "paroxetin \\teva\\\"", "paroxetine",
        "fluoxetin", "fluoxetinhydrochlorid", "fluoxetin \\sandoz\\\"", "fluoxetin \\mylan\\\"", "fluoxetine",
        "amitriptylin \\dak\\\"", "amitriptylinhydrochlorid",  # TCA
        "bupropionhydrochlorid",
        "citalopram \\mylan\\\"", "citalopram \\orion\\\"", "citalopram \\stada\\\"", "citalopram \\teva\\\"", "citalopramhydrobromid",
    },
    "benzodiazepines_sedatives": {
        "alprazolam", "alprazolam \\sandoz\\\"", "alprazolam \\pfizer\\\"", "alprazolam \\krka\\\"", "alprazolam/xanax", "xanax", "ksalol", "ksalol = xanax", "xanax (\\de små\\\")", "xanax (/de små/\")", "bzd", "bzd købt på gaden", "bzd andet", "bzdlsd/ketamin", "benzodiazepin", "benzodiazepiner", "benzodiazepin ukendt",
        "diazepam", "diazepam \\dak\\\"", "diazepam \\2care4\\\"", "diazepam / bzd", "diazepam \\actavis\\\"",
        "diazepam / ukendt",  # new
        "lorazepam", "lorazepam \\orion\\\"",
        "clonazepam", "clonazepam \\mylan\\\"",
        "midazolam", "midazolamhydrochlorid", "midazolam \\fresenius kabi\\\"",
        "midazolam \\actavis\\\"",   # new
        "zolpidem", "zolpidem \\vitabalans\\\"", "zolpidem \\hexal\\\"", "zolpidem \\actavis\\\"", "zolpidem \\2care4\\\"", "zolpidem \\genthon\\\"", "zolpidem tartrat",
        "zopiclone", "zopiclon", "zopiclone \\jubilant\\\"", "zopiclon \\stada\\\"", "zopiclone \\actavis\\\"", "zopiclon/ zolpidem", "zopiclon \\stada\\\"", "zopiclone \\actavis\\\"", "zopiclone \\jubilant\\\"",
        "clobazam", "oxazepam", "oxazepam \\sad\\\"", "oxapax",
        "chlorprothixenhydrochlorid",   # frequently used for sedation (thioxanthene)
        "prometazin", "prometazin/kodein", "promethazin", "promethazinhydrochlorid", # antihistamine/sedative used as hypnotic
        "phenergan",   # promethazine brand (hypnotic/antihistaminic)
        "hydroxyzin", "hydroxyzine", "hydroxyzinhydrochlorid",
        "doxylamin \\sandoz\\\"", "doxylamine", "doxylaminhydrogensuccinat",  # sedative/antihistamine
        "rivotril", # brand for clonazepam (but kept for tracking in misc)
        "chlordiazepoxid" #Risolid
    },
    "opioids_analgesics": {
        "paracetamol", "paracetamol \\teva\\\"", "paracetamol \\actavis\\\"", "paracetamol \\alternova\\\"", "paracetamol \\pfizer\\\"", "paracetamol apotex", "panodil", "panodil zapp", "panodil junior", "panodil extra", "panodil brus",
        "panodil junior: calpol", # new
        "ibuprofen", "ibuprofen \\teva\\\"", "ibuprofen liguid gels", "ibumetin", "ibumetin retard", "ibumetin fra tjekkiet", "ibuprofen \\alternova\\\"",
        "acetylsalicylsyre", "acetylsalicylsyre codeinphosphathemihydrat", "acetylsalicylsyre caffein", "acetylsalicylsyre (ny antagelse)", "acetylsalicylsyre dipyridamol", "acetylsalicylsyre pcm coffein",
        "tramadol", "tramadol retard", "tramadol retard \\hexal\\\"", "tramadol retard \\actavis\\\"", "tramadol \\vita balas\\\"", "tramadol \\actavis\\\"", "tramadol \\krka\\\"", "tramadol santeria", "tramadol \\actavis\\\"",
        "tramadol \\vitabalans\\\"", "tramadolhydrochlorid",
        "tramadol retard \\actavis\\\"", # new
        "tramadol retard \\hexal\\\"",  # new
        "codein", "codeinphosphathemihydrat", "codein \\dak\\\"", "codein/prometazin", "codein \\sad\\\"",
        "codimagnyl \\dak\\\"", "codimagnyl", "kodimagnyl", "kodimagnyl ikke-stoppende \\dak\\\"",
        "oxycodonhydrochlorid", "oxycodonhydrochlorid \\teva\\\"", "oxycodon depot", "oxycodonhydrochlorid \\accord\\\"", "oxycodonhydrochlorid \\g.l.\\\"",
        "oxycodon", "oxycodonhydrochlorid \\accord\\\"", "oxycodonhydrochlorid \\teva\\\"",  # new
        "morphinhydrochlorid (trihydrate)", "morphinsulfat", "morphin", "morfin", "morfin \\sad\\\"", "morfin \\dak\\\"", "morfin depot", "morfin ampuller",
        "buprenorphin", "buprenorphin \\teva\\\"", "buprenorphinhydrochlorid", "buprenorphin naloxon", "buprenorphine \\sandoz\\\"",
        "fentanyl", "fentanyl \\sandoz\\\"", "fentanyl plaster", "fentanylcitrat", "fentanyl plaster", "fentanyl \\orion\\\"", "fentanyl \\pfizer\\\"",
        "tapentadolhydrochlorid",
        "ketogan",
        "paracetamolcoffein codein propyphenazon", # new
        "paracetamol/ caffein codein propyphenazon", "tramadol/ paracetamol", "acetaminophen", "acetaminophen koffein asperin", "acetaminophen phenylephrine",
        "dolol", # opioid (brand name for dextropropoxyphene, or sometimes morphine)
        "prometazin/kodein",
    },
    "anesthetics": {
        "lidocain", "lidocainhydrochlorid", "lidocain kva", "lidocain gel", "lidocaine", "lidocaine hydrochl.", "lidocaine prilocaine", "lidocain tetracain",
        "fluocortolonpivalat lidocainhydrochlorid",   # combination, major component is lidocain
        "ketamin", "ketamin?","ketaminhydrochlorid",
    },
    "antidotes": {
        "naloxon", "naloxonhydrochloriddihydrat",
        "methadonhydrochlorid",
        "disulfiram" #antabus
    },
    "adhd_and_neurostimulants": {
        "ritalin", "ritalin un", "ritalin \\mylan\\\"", "ritalin la", "ritalin modificeret udløsning", "ritalin depot",
        "atomoxetin", "atomoxetin \\teva\\\"", "atomoxetine \\teva\\\"",
        "methylphenidate", "methylphenidate \\sandoz\\\"", "methylphenidate \\hexal\\\"", "methylphenidate \\a-pharma\\\"", "methylphenidate (depot)",
        "methylphenidathydrochlorid", "methylphenidat \\copharma\\\"", "methylphenidat \\2care4\\\"", "methylphenidate \\1a farma\\\"", "methylphenidate \\copharma\\\"", "methylphenidate \\hexal\\\"", "methylphenidate \\sandoz\\\"", "methylphenidate concerta", "methylphenidat \\2care4\\\"", "methylphenidate concerta",
        "methylphenidat", # should cover generic
        "elvanse", "lisdexamfetamindimesilat", # lisdexamfetamine, Elvanse = Vyvanse
        "amfetamin", # amphetamin
        "dexmethylphenidate", "dexamfetamin", "dexamfetamin dimesilat",
        "methylenedioxymethamphetamine", # for tracking
        "atomoxetinhydrochlorid",
    },
    "antiepileptics_moodstabilizers": {
        "lamotrigin", "lamotrigin \\teva\\\"", "lamotrigin \\mylan\\\"", "lamotrigin \\hexal\\\"", "lamotrigin \\stada\\\"", "lamotrigin \\actavis\\\"",
        "lamotrigin \\aurobindo\\\"", "lamotrigin \\ratiopharm\\\"",
        "levetiracetam", "levetiracetam \\teva\\\"", "levetiracetam \\orion\\\"", "levetiracetam \\bluefish\\\"", "levetiracetam \\ratiopharm\\\"", "levetiracetam \\sandoz\\\"", "levetiracetam \\stada\\\"", "levetiracetam \\accord\\\"", "levetiracetam \\lek\\\"", "levetiracetam \\mylan\\\"",
        "carbamazepin", "carbamazepin \\orion\\\"", "carbamazepin \\dak\\\"",
        "valproat", "valproat \\sandoz\\\"", "natriumvalproat",
        "oxcarbazepin", "oxcarbazepin \\mylan\\\"",
        "topiramat", "topiramat \\actavis\\\"", "topiramat \\pfizer\\\"", "topiramat \\orion\\\"",
        "gabapentin", "gabapentin \\teva\\\"", "gabapentin \\sandoz\\\"", "gabapentin \\bluefish\\\"", "gabapentin \\a-pharma\\\"", "gabapentin \\pcd\\\"", "gabapentin \\orifarm\\\"", "gabapentin \\pfizer\\\"",
        "gabapentin \\sandoz\\\"", "gabapentin \\teva\\\"",
        "pregabalin", "pregablain", "pregabalin sandoz",
        "zonisamid",
        "oxabenz",
        "clobazam",
        "lamictal",
        "lithiumcarbonat", "lithiumcitrat", # mood stabilizer
    },
    "antidiabetics": {
        "metformin", "metformin \\teva\\\"", "metformin \\sandoz\\\"", "metformin \\vitabalans\\\"", "metforminhydrochlorid", "mediscrub med glycerin", "dapagliflozin metformin", "dapagliflozin propandiol monohydrat", "dapagliflozin / metformin", "linagliptin", "semaglutid", "semaglutide", "liraglutid", "glimepirid", "glipizid", "empagliflozin", "canagliflozin"
    },
    "antibiotics_antimicrobials": {
        "amoxicillin", "amoxicillintrihydrat", "amoxicillintrihydrat clavulansyre", "amoxicillin clavulansyre", "amoxicillin clavulansyre \\actavis\\\"", "amoxicillin \\mip\\\"", "cefuroxim",
        "ceftriaxon", "ceftriaxon \\villerton\\\"", "ceftriaxonnatrium", "cefuroximaxetil", "cefuroxim benzoat", "cephalexin", "clindamycin", "clindamycinhydrochlorid", "linezolid", "clarithromycin", "roxithromycin", "azithromycin", "azithromycin \\teva\\\"", "vancomycin", "doxycyclin", "doxycyclinmonohydrat", "doxycyclinhyclat", "rifampicin", "nitrofurantoin", "nitrofurantoin \\dak\\\"",
        "ciprofloxacin", "ciprofloxacinlactat",  # new fluoroquinolone
        "metronidazol", "metronidazol \\teva\\\"", "metronidazol \\baxter\\\"", "metronidazolbenzoat", "nitazoxanide", "sulfametizol", "sulfamethoxazol trimethoprim"
        "mecillinam", "ampicillintrihydrat", "gentamicinsulfat", "primcillin", "pivmecillinamhydrochlorid"
    },
    "antihistamines_allergy": {
        "cetirizin", "cetirizindihydrochlorid", "cetirizin \\teva\\\"", "cetirizin \\pcd\\\"", "cetirizin \\orifarm\\\"",
        "loratadin", "loratadin \\stada\\\"",
        "desloratadin", "desloratadine \\stada\\\"", "desloratadine \\mylan\\\"",
        "fexofenadin", "fexofenadinhydrochlorid \\ivax\\\"",
        "mepyramin", "mepyramin 2%", "ebastin",
        "hydroxizin",
        "doxylamin \\sandoz\\\"", "doxylamine", "doxylaminhydrogensuccinat",  # also antihistamine class, but see also under sedatives
        "paracetamol klorfeniramin maleat pseudoephedrin",  # combo with antihistamine
        "acrivastin",
    },
    "electrolytes_supplements": {
        "kaliumchlorid", "kaliumpermanganat", "kaliumhydroxid", "kaliumdihydrogenphosphat", "kaliumbicrom", "kaliumchromat", "kaliumcitrat"
    },
    "gi_drugs": {
        "omeprazol", "omeprazol \\teva\\\"", "omeprazol \\mylan\\\"", "omeprazol \\aurobindo\\\"", "omeprazolmagnesium",
        "pantoprazol", "pantoprazole \\teva\\\"", "pantoprazol \\actavis\\\"", "pantoprazol \\nycomed\\\"", "pantoprazol \\ranbaxy\\\"", "pantoprazol \\jubilant\\\"", "pantoprazol \\boehringer ingelheim\\\"", "pantoprazol \\bluefish\\\"",
        "lansoprazol", "lansoprazol \\krka\\\"", "lansoprazol \\teva\\\"",
        "esomeprazol", "esomeprazol \\sandoz\\\"", "esomeprazol \\ranbaxy\\\"", "esomeprazol \\spi\\\"", "esomeprazol \\navamedic\\\"", "esomeprazolmagnesiumdihydrat",
        # "paracetamol klorfeniramin maleat pseudoephedrin" - multi-class product, already in allergy
    },
    "muscle_relaxants": {
        "baclofen", "baclofen \\mylan\\\"",
        "cyclizinhydrochlorid",  # anti-emetic/antivertigo with relaxing properties
    },
    "antipsychotics_neuroleptics": {
        "olanzapin", "olanzapin \\hexal\\\"", "olanzapin \\sandoz\\\"", "olanzapin \\actavis\\\"", "olanzapin \\pfizer\\\"", "olanzapin \\pensa\\\"", "olanzapin \\awd\\\"", "olanzapin \\normon\\\"",
        "clozapin", "clozapin \\sandoz\\\"", "clozapin \\hexal\\\"", "clozapin \\orifarm\\\"", "clozapin \\sandoz\\\"", "clozapin \\hexal\\\"",
        "aripiprazol", "abilify", # brand
        "zuclopenthixol", "zuclopenthixoldihydrochlorid", "zuclopenthixoldecanoat",
        "ziprasidon", "ziprasidon \\teva\\\"", "ziprasidonmesilat", "ziprasidon \\actavis\\\"",
        "haloperidol",
        "quetiapin \\hexal\\\"", "quetiapin \\lannacher\\\"", "quetiapin \\krka\\\"", "quetiapin \\medis\\\"", "quetiapin \\ratiopharm\\\"", "quetiapin \\stada\\\"", "quetiapin \\actavis\\\"", "quetiapin \\pfizer\\\"", "quetiapin", "quetiapin fumarat", "quetiapin \\sandoz\\\"",
        "quetiapin  (ikke depot)", "quetiapin (depot tbl)", "quetiapin \\fair-med\\\"", "quetiapin \\lambda\\\"", "quetiapin \\mylan\\\"", "quetiapin \\orion\\\"", "quetiapin prolong", "quetiapine \\teva\\\"", "quetiapin \\winthrop\\\"", # all new
        "chlorprothixenhydrochlorid",   # thioxanthene neuroleptic, also in sedatives due to hypnotic use
        "pipamperonhydrochlorid", # typical neuroleptic
        "truxal", # brand name for chlorprothixene
        "risperidon",
    },
    "anti_parkinson_alzheimers": {
        "levodopa", "levodopa/benserazid \\teva\\\"", "carbidopa levodopa", "carbidopa levodopa \\sandoz\\\"",
        "amantadin", # anti-parkinson
        "donepezil", "donepezil \\jubilant\\\"", "donepezil \\pfizer\\\"",
        "galantaminhydrobromid",
    },
    "thyroid_medications": {
        "levothyroxin", "levothyroxinnatrium"
    },
    "anticancer_antimetabolite": {
        "metotrexat", "methotrexat", "methotrexat \\sandoz\\\"", "methotrexat \\2care4\\\"",
        "thioguanin",
        "ondansetron",
    },
    "others_misc": {
        "allopurinol", "allopurinol \\teva\\\"", "allopurinol \\dak\\\"", "acetazolamid", "colchicin",
        "dexametason", "dexamethason", "dexamethasonnatriumphosphat", "dexamethason \\abcur\\\"",
        "paradoxtrin",  # unclear, possibly error or rare
        "prednisolon",
        "salbutamol", # SABA, asthma drug
        "spiriva",
        "melatonin", # hormone/sleep aid, but not a benzodiazepine
        "natriumalendronat",
        "natriumpicosulfat", #laxative
        "estradiolhemihydrat",
        "norethisteronacetat",
        "fludrocortisonacetat" #binyrebarkhormon
        "nivolumab",
        
    }
}

# %%
# Removing manufacturer from know_medicines_in_categories
import re

def remove_manufacturer(entry):
    # Remove patterns like ' \some-company\"', handling possible double-quotes and backslashes
    return re.sub(r'\s*\\[^\\]*\\"', '', entry).strip()

medicines_without_manufacturer = {}

for category, medicines in know_medicines_in_categories.items():
    cleaned_entries = set()
    for medicine in medicines:
        cleaned_entries.add(remove_manufacturer(medicine))
    medicines_without_manufacturer[category] = cleaned_entries

# Example: print out the cleaned dict for one category
from pprint import pprint

pprint(medicines_without_manufacturer)
# Out:
# {'adhd_and_neurostimulants': {'amfetamin',
#                               'atomoxetin',
#                               'atomoxetine',
#                               'atomoxetinhydrochlorid',
#                               'dexamfetamin',
#                               'dexamfetamin dimesilat',
#                               'dexmethylphenidate',
#                               'elvanse',
#                               'lisdexamfetamindimesilat',
#                               'methylenedioxymethamphetamine',
#                               'methylphenidat',
#                               'methylphenidate',
#                               'methylphenidate (depot)',
#                               'methylphenidate concerta',
#                               'methylphenidathydrochlorid',
#                               'ritalin',
#                               'ritalin depot',
#                               'ritalin la',
# ...

# %%
# Removing manufacturer in csv
import re
import csv

def remove_manufacturer(entry):
    # Split at first occurrence of ' \'
    return entry.split(' \\')[0].strip()

unique_meds_in_csv = set()
with open('unique_values_generated.csv', newline='', encoding='utf8') as csvfile:
    reader = csv.reader(csvfile, delimiter='\t')
    for row in reader:
        # The medicine name is in the first column
        med = row[0].strip()
        if med:
            cleaned_med = remove_manufacturer(med)
            unique_meds_in_csv.add(cleaned_med)

# Example: print out the cleaned medicines
from pprint import pprint

pprint(unique_meds_in_csv)
# Out:
# {'abilify',
#  'alprazolam',
#  'alprazolam / xanax',
#  'amantadin',
#  'amfetamin',
#  'amiloridhydrochlorid dihydrat hydrochlorthiazid',
#  'amitriptylin',
#  'amitriptylinhydrochlorid',
#  'amlodipinmaleat',
#  'amoxicillintrihydrat',
#  'aripiprazol',
#  'atenolol',
#  'atomoxetinhydrochlorid',
#  'atorvastatin',
#  'baclofen',
#  'bisoprolol',
#  'bupropionhydrochlorid',
#  'candesartan',
#  'cannabis',
#  'cephalexin',
#  'chlordiazepoxid',
#  'chlorprothixenhydrochlorid',
#  'ciprofloxacin',
#  'ciprofloxacinlactat',
#  'citalopram',
#  'citalopramhydrobromid',
#  'clindamycin',
#  'clindamycinhydrochlorid',
#  'clonazepam',
#  'clonidin',
#  'clopidogrel',
#  'clozapin',
#  'codein',
#  'codein/prometazin',
#  'codeinphosphathemihydrat',
#  'codimagnyl',
#  'cyclizinhydrochlorid',
#  'dexamfetamin',
#  'diazepam',
#  'diazepam / ukendt',
#  'digoxin',
#  'dolol',
#  'donepezil',
#  'doxylamin',
#  'doxylamine',
#  'doxylaminhydrogensuccinat',
#  'duloxetin',
# ...

# %%
#Cross checking csv to code
# 2. Flatten all category sets into one set for lookup
meds_in_categories = set()
for cat_set in medicines_without_manufacturer.values():
    meds_in_categories.update(cat_set)

# 3. Cross-check
missing_from_categories = unique_meds_in_csv - meds_in_categories
added_in_categories_not_in_csv = meds_in_categories - unique_meds_in_csv

# 4. Print results
print("Entries in unique_values_generated.csv that are NOT in any category:")
for med in sorted(missing_from_categories):
    print("  " + med)
print(f"\nTotal missing from medicines_without_manufacturer: {len(missing_from_categories)}\n")

print("Entries in categories that are NOT in unique_values_generated.csv:")
for med in sorted(added_in_categories_not_in_csv):
    print("  " + med)
print(f"\nTotal missing from unique_values_generated.csv: {len(added_in_categories_not_in_csv)}\n")

print(f"Total in CSV: {len(unique_meds_in_csv)}")
print(f"Total in categories: {len(meds_in_categories)}")
print(f"Total overlap: {len(unique_meds_in_csv & meds_in_categories)}")
# Out:
# Entries in unique_values_generated.csv that are NOT in any category:
#   alprazolam / xanax
#   cannabis
#   fluortandpasta
#   mdma
#   methylphenidat (depot)
#   toiletblok
#   venlafaxin agp
#   xanax (\de små\")"
#
# Total missing from medicines_without_manufacturer: 8
#
# Entries in categories that are NOT in unique_values_generated.csv:
#   acetaminophen
#   acetaminophen koffein asperin
#   acetaminophen phenylephrine
#   acetazolamid
#   acetylsalicylsyre
#   acetylsalicylsyre (ny antagelse)
#   acetylsalicylsyre caffein
#   acetylsalicylsyre codeinphosphathemihydrat
#   acetylsalicylsyre dipyridamol
#   acetylsalicylsyre pcm coffein
#   acrivastin
#   allopurinol
#   alprazolam/xanax
#   amlodipin
#   amlodipinbesilat
#   amlodipinbesilat valsartan
#   amlodipine
#   amlodipinmesilat
#   amoxicillin
#   amoxicillin clavulansyre
#   amoxicillintrihydrat clavulansyre
#   atomoxetin
#   atomoxetine
#   azithromycin
#   benzodiazepin
#   benzodiazepin ukendt
#   benzodiazepiner
# ...

# %%
# Filtering and removing rows without medicines present
import re
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# --- 1. Get the list of all allowed starts (union of all sets) ---
meds_set = set()
for v in medicines_without_manufacturer.values():
    meds_set.update([s.lower() for s in v])
# Sort by length desc so longer matches are checked first (prevents e.g. 'paracetamol' before 'paracetamol apotex')
meds_list = sorted(meds_set, key=len, reverse=True)

# For regex, escape possible problematic patterns
meds_regex = re.compile(r'^(' + '|'.join(re.escape(med) for med in meds_list) + r')\b')

generisk_cols = [f'[generisk navn(gift{i})]'.lower() for i in range(1, 16)]
navn_cols = [f'[navn(gift{i})]'.lower() for i in range(1, 16)]

def row_has_valid_medicine(row):
    for col in generisk_cols + navn_cols:
        # Some entries might be NaN
        entry = row[col]
        if pd.isna(entry):
            continue
        entry_lower = str(entry).strip().lower()
        if meds_regex.match(entry_lower):
            return True
    return False

# --- 2. Apply filter to 'young' and 'old', and print a preview of excluded rows ---

def filter_dataframe_and_preview(df, label):
    keep_mask = df.apply(row_has_valid_medicine, axis=1)
    filtered = df[keep_mask]
    dropped = df[~keep_mask]
    print(f"\n{'='*40}\nRows DELETED from '{label}':")
    # Show up to 10 dropped rows, printing the medicine columns for review
    display(dropped[generisk_cols + navn_cols].head(200))
    print(f"\nTotal rows kept: {filtered.shape[0]}, dropped: {dropped.shape[0]}")
    return filtered

young_filtered = filter_dataframe_and_preview(young, 'young')
old_filtered = filter_dataframe_and_preview(old, 'old')

# Now you have 'young_filtered' and 'old_filtered' as your filtered data.
# Out:
# ...
# Rows DELETED from 'young':
#                                [generisk navn(gift1)] [generisk navn(gift2)]  \
# 1                                                 NaN                    NaN
# 2                                              Ukendt                    NaN
# 3                                    Ukendt rusmiddel                    NaN
# 5                                                 NaN                    NaN
# 7                                                 NaN                    NaN
# 8                                           Persulfat                    NaN
# 9                                 Dinitrogenoxid 100%                    NaN
# 10                                        metasilikat                    NaN
# 11                                       ZINKGLUCONAT                    NaN
# 12                                                NaN                    NaN
# 13                                         Polystyren                    NaN
# ...

# %%
# #ToDo:
# # combine all the 'årsag' 

# Filter out the non-medicine related rows from the categories below.
#x AMED: 4
#x BIO: 22795
# DIVERSE: 14213
# KEMI: 51993
# MED: 51811
# RUS: 10893
#x SPECIALDONOTDELETE: 8010 
# ZZMED: 29477
#Visit each type and convert to MED as appropriate

#Filter all the MED to see if there are non-medicine items (count them)

#Next step is: import data from official lists to create list of medications.
#https://laegemiddelstyrelsen.dk/da/godkendelse/godkendelse-af-medicin/lister-over-godkendte-og-afregistrerede-laegemidler/saadan-bruger-du-listen-over-afregistrerede-laegemidler/
#https://laegemiddelstyrelsen.dk/da/godkendelse/godkendelse-af-medicin/lister-over-godkendte-og-afregistrerede-laegemidler/saadan-bruger-du-listen-over-godkendte-laegemidler/
