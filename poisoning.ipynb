# %%
print('starting3')
# Out:
# starting3

# %%
#!pip install msoffcrypto-tool
# needed to read password-protected file
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [msoffcrypto-tool]
#    ---------------------------------------- 2/2 [msoffcrypto-tool]
#
# ...

# %%
from getpass import getpass
import io
import pandas as pd
import msoffcrypto

file_path = 'YOUR_FILE.xlsx'  # change this to your file path
password = getpass("Enter Excel password: ")

decrypted = io.BytesIO()
with open(file_path, "rb") as f:
    office = msoffcrypto.OfficeFile(f)
    office.load_key(password=password)
    office.decrypt(decrypted)

df = pd.read_excel(decrypted)
df.head()

# %%
import pandas as pd
name=r"C:\Users\danam\OneDrive\Desktop\Bachelorprojekt\Tidligere excel bearbejdninger\Alle Giftlinjen 2018-2022 (anonym) Aldersfordelt - Kopi.xlsx"
sheet_y="Alder<70"
sheet_o="Alder>70"

df = pd.read_excel(name, sheet_name=sheet_y)

# View the first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 6
#       3 sheet_y="Alder<70"
#       4 sheet_o="Alder>70"
# ----> 6 df = pd.read_excel(name, sheet_name=sheet_y)
#       8 # View the first few rows
#       9 df.head()
#
# File c:\Users\danam\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
# ...
